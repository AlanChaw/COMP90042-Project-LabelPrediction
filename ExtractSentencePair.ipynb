# %% [markdown]
# # Extract claim_evidence pairs from training set

# %% [markdown]
# ## Construct index dict

# %%
import os
import json

wiki_file_path = "./new-wiki-pages-text/"
train_file_path = "./JSONFiles/" + "train.json"
dev_file_path = "./JSONFiles/" + "devset.json"

train_output_path = "./TrainSentence/" + "training.csv"
dev_output_path = "./TrainSentence/" + "dev.csv"

# create index for evidences
evi_index = {}
head_index = {}
for file in os.listdir(wiki_file_path):
    print("processing file: " + file)
    file_name = wiki_file_path + file
    with open(file=file_name) as f:
        lines = f.readlines()
        for i in range(len(lines)):
            words = lines[i].split(" ")
            head = words[0]

            try:
                evi = (words[0], int(words[1]))
                evi_index.update({
                evi: (file, i)
                })
            except ValueError as e:
                continue
                
            if head in head_index.keys():
                head_index[head].append(int(words[1]))
            else:
                head_index.update({
                    head: [int(words[1])]
                })
# Out:
# processing file: wiki-007.txt
# processing file: wiki-081.txt
# processing file: wiki-008.txt
# processing file: wiki-107.txt
# processing file: wiki-078.txt
# processing file: wiki-050.txt
# processing file: wiki-098.txt
# processing file: wiki-055.txt
# processing file: wiki-043.txt
# processing file: wiki-002.txt
# processing file: wiki-044.txt
# processing file: wiki-082.txt
# processing file: wiki-072.txt
# processing file: wiki-070.txt
# processing file: wiki-011.txt
# processing file: wiki-053.txt
# processing file: wiki-010.txt
# processing file: wiki-022.txt
# processing file: wiki-030.txt
# processing file: wiki-091.txt
# processing file: wiki-077.txt
# processing file: wiki-009.txt
# processing file: wiki-031.txt
# processing file: wiki-065.txt
# processing file: wiki-102.txt
# processing file: wiki-006.txt
# processing file: wiki-052.txt
# processing file: wiki-092.txt
# processing file: wiki-075.txt
# processing file: wiki-012.txt
# processing file: wiki-059.txt
# processing file: wiki-064.txt
# processing file: wiki-023.txt
# processing file: wiki-068.txt
# processing file: wiki-073.txt
# processing file: wiki-004.txt
# processing file: wiki-109.txt
# processing file: wiki-054.txt
# processing file: wiki-103.txt
# processing file: wiki-066.txt
# processing file: wiki-020.txt
# processing file: wiki-100.txt
# processing file: wiki-034.txt
# processing file: wiki-104.txt
# processing file: wiki-069.txt
# processing file: wiki-036.txt
# processing file: wiki-090.txt
# processing file: wiki-038.txt
# processing file: wiki-079.txt
# processing file: wiki-032.txt
# processing file: wiki-096.txt
# processing file: wiki-046.txt
# processing file: wiki-028.txt
# processing file: wiki-080.txt
# processing file: wiki-099.txt
# processing file: wiki-033.txt
# processing file: wiki-017.txt
# processing file: wiki-019.txt
# processing file: wiki-089.txt
# processing file: wiki-105.txt
# processing file: wiki-024.txt
# processing file: wiki-060.txt
# processing file: wiki-085.txt
# processing file: wiki-106.txt
# processing file: wiki-025.txt
# processing file: wiki-058.txt
# processing file: wiki-003.txt
# processing file: wiki-108.txt
# processing file: wiki-005.txt
# processing file: wiki-042.txt
# processing file: wiki-087.txt
# processing file: wiki-048.txt
# processing file: wiki-040.txt
# processing file: wiki-071.txt
# processing file: wiki-095.txt
# processing file: wiki-021.txt
# processing file: wiki-057.txt
# processing file: wiki-101.txt
# processing file: wiki-097.txt
# processing file: wiki-041.txt
# processing file: wiki-029.txt
# processing file: wiki-083.txt
# processing file: wiki-026.txt
# processing file: wiki-062.txt
# processing file: wiki-049.txt
# processing file: wiki-056.txt
# processing file: wiki-045.txt
# processing file: wiki-047.txt
# processing file: wiki-094.txt
# processing file: wiki-063.txt
# processing file: wiki-074.txt
# processing file: wiki-018.txt
# processing file: wiki-051.txt
# processing file: wiki-067.txt
# processing file: wiki-016.txt
# processing file: wiki-001.txt
# processing file: wiki-013.txt
# processing file: wiki-037.txt
# processing file: wiki-086.txt
# processing file: wiki-084.txt
# processing file: wiki-035.txt
# processing file: wiki-015.txt
# processing file: wiki-093.txt
# processing file: wiki-039.txt
# processing file: wiki-014.txt
# processing file: wiki-088.txt
# processing file: wiki-061.txt
# processing file: wiki-076.txt
# processing file: wiki-027.txt

# %%
# head_index.get("José_Ferrer")

# %% [markdown]
# ## Build training set according to file

# %%
import pandas as pd
import linecache
import numpy as np
import random
from sklearn.utils import shuffle

use_file = 1    # 0 for training set , 1 for dev set

# read training data
if use_file == 0:
    with open(train_file_path, 'r') as f:
        train = json.load(f)
elif use_file == 1:
    with open(dev_file_path, 'r') as f:
        train = json.load(f)

def get_evi_text(evi) -> str:
    evidence = (evi[0], int(evi[1]))
    file_index_tuple = evi_index.get(evidence)
    file = wiki_file_path + file_index_tuple[0]
    line_num = file_index_tuple[1]
    evi_text = linecache.getline(file,line_num + 1)
    evi_text = evi_text[2: len(evi_text) + 1]
    words = evi_text.split(" ")[2: len(evi_text)]
    evi_text = " ".join(words)
    return evi_text
    

claim_list = []
evi_list = []
claim_evi_list = []
label_list = []

np.random.seed(3)

for key in train.keys():
    item = train.get(key)
    evidence_list = item['evidence']
    if len(evidence_list) == 0:
        continue
    claim = item['claim']
        
    head_set = set()
    for evi in evidence_list:
        head = evi[0]
        head_set.add(head)
        
    for head in head_set:
        sentence_numbers = head_index.get(head)
        if sentence_numbers is None:
            continue
        for number in sentence_numbers:
            query_combination = [head, number]
            evidence_text = get_evi_text(query_combination)
            
            if query_combination in evidence_list:
                label_list.append(1)
            else:
                probability = np.random.rand()
                if probability > 0.2:
                    continue
                label_list.append(0)
                
            claim_list.append(claim)
            evi_list.append(evidence_text)
            claim_evi_list.append(claim + " ||| " + evidence_text)

result_dict = {
    "claim": claim_list,
    "evidence": evi_list,
    "claim_evi_pair": claim_evi_list,
    "label": label_list
}
result_df = pd.DataFrame(result_dict)
result_df = shuffle(result_df)

if use_file == 0:
    result_df.to_csv(train_output_path, index=False)
elif use_file == 1:
    result_df.to_csv(dev_output_path, index=False)

# %%
result_df
# Out:
#                                                    claim  \
# 4284    2016 Tour de France was not won by Chris Froome.
# 11535                   Matthias Corvinus had a library.
# 2255   David Packouz had something to do with weapons...
# 6386                 José Ferrer was an actor in movies.
# 3211   Camden, New Jersey is the home of a school tha...
# 3229                           Poldark has three series.
# 1769             In a Lonely Place was based on a novel.
# 4897         A Floppy disk is unrelated to disk storage.
# 2295          St. Anger was released by Sub Pop Records.
# 1366   Anushka Sharma won a Filmfare Award for Best S...
# 1195   Artpop was only Gaga's fifth consecutive numbe...
# 8675                Herculaneum's ruins are near Naples.
# 10790   Renato Balestra came from a family of mechanics.
# 2824   Byron Howard co-directed Zootopia with Jill St...
# 3245            Exercise is beneficial for heart health.
# 534        English people are unconnected to the Angles.
# 1172    The Adventures of Pluto Nash stars Eddie Murphy.
# 1810   Alice Cooper's full name is Vincent Damon Furn...
# 2761                        Humphrey Bogart does acting.
# 7799                 Wales' population rapidly expanded.
# 2505                Harold Macmillan worked in politics.
# 4041   There is an epic historical romantic drama nam...
# 11329        Arizona is not a part of the United States.
# 6849   The New Orleans Pelicans play in the Eastern C...
# 2297          St. Anger was released by Sub Pop Records.
# 2480                           Janet Leigh was a person.
# 4250   Moonlight was filmed on a beach in Miami, Flor...
# 4985      Jennifer Lopez married a minimum of two times.
# 6374         Sancho Panza is a character in Don Quixote.
# 11735  Wales has a large region rich in coal deposits...
# ...                                                  ...
# 9923                    Camden, New Jersey is a country.
# 9907   Prescott, Arizona is outside of the United Sta...
# 3615   Sheryl Lee has yet to appear in a film as of 2...
# 11746                  Anne Rice was born in the 1950's.
# 11697   The Wallace mentions events that never happened.
# 1234                        The Cincinnati Kid is a boy.
# 8972       Sayyeshaa only works with American directors.
# 7652                                Rabies is a disease.
# 5864                        Michigan is an Indian state.
# 2062   Raees (film) stars an Indian film actor born i...
# 2183   Guatemala civil right war was fought between t...
# 2513                Harold Macmillan worked in politics.
# 5849   Victoria (Dance Exponents song) was a book rel...
# 4718                         Paramore is from an island.
# 5639        Scotty Moore was only a mechanical engineer.
# 2083                 You Belong with Me is a blues song.
# 9804              Recovery is a solo album by Lil Wayne.
# 5888                               Paramore is Canadian.
# 9900   Marvel vs. Capcom: Infinite retains the series...
# 5112                Justin Chatwin performs as an actor.
# 9342   The undergraduate college of Harvard Universit...
# 1191   Artpop was only Gaga's fifth consecutive numbe...
# 5835    John Krasinski played Jim Halpert on The Office.
# 10295                  Anne Rice was born in the 1960's.
# 9201   The King and I is based on a novel by a Britis...
# 1088     Oscar de la Hoya retired from fighting in 1990.
# 11286    A song on Virgin Records was released by Mel B.
# 6721   David Packouz is completely uninterested in mu...
# 1515                 Raees (film) stars an Indian actor.
# 4827                   Manmohan Singh was elected again.
#
#                                           claim_evi_pair  \
# 4284   2016 Tour de France was not won by Chris Froom...
# 11535  Matthias Corvinus had a library. ||| Matthias ...
# 2255   David Packouz had something to do with weapons...
# 6386   José Ferrer was an actor in movies. ||| Tony A...
# 3211   Camden, New Jersey is the home of a school tha...
# 3229   Poldark has three series. ||| Poldark 2015 TV ...
# 1769   In a Lonely Place was based on a novel. ||| In...
# 4897   A Floppy disk is unrelated to disk storage. ||...
# 2295   St. Anger was released by Sub Pop Records. |||...
# 1366   Anushka Sharma won a Filmfare Award for Best S...
# 1195   Artpop was only Gaga's fifth consecutive numbe...
# 8675   Herculaneum's ruins are near Naples. ||| Naple...
# 10790  Renato Balestra came from a family of mechanic...
# 2824   Byron Howard co-directed Zootopia with Jill St...
# 3245   Exercise is beneficial for heart health. ||| H...
# 534    English people are unconnected to the Angles. ...
# 1172   The Adventures of Pluto Nash stars Eddie Murph...
# 1810   Alice Cooper's full name is Vincent Damon Furn...
# 2761   Humphrey Bogart does acting. ||| Humphrey Boga...
# 7799   Wales' population rapidly expanded. ||| Wales ...
# 2505   Harold Macmillan worked in politics. ||| Harol...
# 4041   There is an epic historical romantic drama nam...
# 11329  Arizona is not a part of the United States. ||...
# 6849   The New Orleans Pelicans play in the Eastern C...
# 2297   St. Anger was released by Sub Pop Records. |||...
# 2480   Janet Leigh was a person. ||| Janet Leigh Disc...
# 4250   Moonlight was filmed on a beach in Miami, Flor...
# 4985   Jennifer Lopez married a minimum of two times....
# 6374   Sancho Panza is a character in Don Quixote. ||...
# 11735  Wales has a large region rich in coal deposits...
# ...                                                  ...
# 9923   Camden, New Jersey is a country. ||| Camden, N...
# 9907   Prescott, Arizona is outside of the United Sta...
# 3615   Sheryl Lee has yet to appear in a film as of 2...
# 11746  Anne Rice was born in the 1950's. ||| Anne Ric...
# 11697  The Wallace mentions events that never happene...
# 1234   The Cincinnati Kid is a boy. ||| Steve McQueen...
# 8972   Sayyeshaa only works with American directors. ...
# 7652   Rabies is a disease. ||| Rabies The disease ca...
# 5864   Michigan is an Indian state. ||| Michigan Mich...
# 2062   Raees (film) stars an Indian film actor born i...
# 2183   Guatemala civil right war was fought between t...
# 2513   Harold Macmillan worked in politics. ||| Harol...
# 5849   Victoria (Dance Exponents song) was a book rel...
# 4718   Paramore is from an island. ||| Paramore Their...
# 5639   Scotty Moore was only a mechanical engineer. |...
# 2083   You Belong with Me is a blues song. ||| You Be...
# 9804   Recovery is a solo album by Lil Wayne. ||| Rec...
# 5888   Paramore is Canadian. ||| Brand New Eyes It wa...
# 9900   Marvel vs. Capcom: Infinite retains the series...
# 5112   Justin Chatwin performs as an actor. ||| Justi...
# 9342   The undergraduate college of Harvard Universit...
# 1191   Artpop was only Gaga's fifth consecutive numbe...
# 5835   John Krasinski played Jim Halpert on The Offic...
# 10295  Anne Rice was born in the 1960's. ||| Anne Ric...
# 9201   The King and I is based on a novel by a Britis...
# 1088   Oscar de la Hoya retired from fighting in 1990...
# 11286  A song on Virgin Records was released by Mel B...
# 6721   David Packouz is completely uninterested in mu...
# 1515   Raees (film) stars an Indian actor. ||| Shah R...
# 4827   Manmohan Singh was elected again. ||| Manmohan...
#
#                                                 evidence  label
# 4284   2016 Tour de France A total of 198 riders from...      1
# 11535  Matthias Corvinus After conducting several mil...      0
# 2255   Efraim Diveroli The U.S. government suspended ...      0
# 6386   Tony Award The Tony Awards are also considered...      0
# 3211   Camden, New Jersey Pollution is an ongoing iss...      0
# 3229   Poldark 2015 TV series Poldark is a British-Am...      1
# 1769   In a Lonely Place The script was adapted by Ed...      1
# 4897   Floppy disk While floppy disk drives still hav...      0
# 2295   St. Anger St. Anger is the eighth studio album...      1
# 1366   Anushka Sharma Sharma received critical praise...      0
# 1195   Artpop It was included in several year-end lis...      0
# 8675   Naples A larger colony -- initially known as P...      0
# 10790  Renato Balestra However , even from the earlie...      0
# 2824   Zootopia The film was directed by Byron Howard...      1
# 3245   Heart In humans , the heart is located between...      0
# 534    English people Their ethnonym is derived from ...      1
# 1172   The Adventures of Pluto Nash The Adventures of...      1
# 1810   Alice Cooper Furnier adopted the band 's name ...      0
# 2761   Humphrey Bogart His first great success was as...      1
# 7799   Wales At the dawn of the Industrial Revolution...      1
# 2505   Harold Macmillan Maurice Harold Macmillan , 1s...      1
# 4041   Baz Luhrmann Mark Anthony `` Baz '' Luhrmann b...      0
# 11329  Phoenix, Arizona Phoenix is the capital and mo...      1
# 6849   Western Conference NBA All playoff series are ...      0
# 2297   St. Anger The artwork was created by Pushead ,...      0
# 2480   Janet Leigh Discovered by actress Norma Sheare...      0
# 4250   Moonlight 2016 film Filmed in Miami , Florida ...      1
# 4985   Jennifer Lopez Lopez gained her first high-pro...      0
# 6374   Sancho Panza Sancho acts as squire to Don Quix...      0
# 11735  South Wales Coalfield The South Wales Coalfiel...      1
# ...                                                  ...    ...
# 9923   Camden, New Jersey On March 13 , 1844 , Camden...      1
# 9907   Prescott, Arizona According to the 2010 Census...      1
# 3615   Sheryl Lee After studying acting in college , ...      1
# 11746  Anne Rice In addition to her vampire novels , ...      0
# 11697  The Wallace poem The poem is historically inac...      1
# 1234   Steve McQueen His other popular films include ...      1
# 8972   Ajay Devgn The same year he gave another criti...      0
# 7652   Rabies The disease can only be diagnosed after...      1
# 5864   Michigan Michigan also has 64,980 inland lakes...      0
# 2062   Shah Rukh Khan He then rose to prominence afte...      0
# 2183   Guatemala The territory of modern Guatemala on...      0
# 2513   Harold Macmillan In international affairs , Ma...      1
# 5849   Victoria Dance Exponents song The song was sel...      1
# 4718   Paramore Their fifth studio album After Laught...      0
# 5639   Scotty Moore All I wanted to do in the world w...      0
# 2083   You Belong with Me The video 's plot centers o...      0
# 9804   Recovery Eminem album It was released on June ...      1
# 5888   Brand New Eyes It was written by band members ...      0
# 9900   Marvel vs. Capcom-COLON- Infinite The series '...      1
# 5112   Justin Chatwin Chatwin is best known for playi...      1
# 9342   Harvard University The undergraduate college b...      1
# 1191   Artpop It displays an intentional `` lack of m...      0
# 5835   John Krasinski The Hollars 2017 which he cowro...      0
# 10295  Anne Rice Anne Rice born Howard Allen Frances ...      1
# 9201   The King and I In later revivals , Brynner cam...      0
# 1088   Manny Pacquiao Emmanuel Dapidran `` Manny '' P...      0
# 11286  Mel B However , Brown resigned from the show a...      0
# 6721   David Packouz David Mordechai Packouz born Feb...      1
# 1515   Shah Rukh Khan Shah Rukh Khan born Shahrukh Kh...      1
# 4827   Manmohan Singh In 2004 , when the Congress-led...      0
#
# [11982 rows x 4 columns]

# %%
result_df['label'].describe()
# Out:
# count    11982.000000
# mean         0.471624
# std          0.499215
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: label, dtype: float64
